# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
#city = "Denver"

query_url= url + "appid=" + weather_api_key + "&q=" + city
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=5ed795c09c212a19bdc0e2a9c1b8965d&q=busselton

# %%
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# %%
pprint(weather_json)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.65, 'lon': 115.3333},
#  'dt': 1612042449,
#  'id': 2075265,
#  'main': {'feels_like': 289.32,
#           'humidity': 79,
#           'pressure': 1013,
#           'temp': 288.96,
#           'temp_max': 289.82,
#           'temp_min': 287.59},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'id': 2008303,
#          'sunrise': 1612042772,
#          'sunset': 1612092270,
#          'type': 3},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 67, 'gust': 2.24, 'speed': 0.45}}

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#lat = []
#long = []
#City	Lat	Lng	Max Temp	Humidity	Cloudiness	Wind Speed	Country	Date

city_data=[]
lat_data=[]
lng_data=[]
max_temp_data=[]
humidity_data=[]
cloudiness_data=[]
wind_speed_data=[]
country_data=[]
date_data=[]

counter = 0

 
for each_city in cities[:]:
    query_url = f'{url}q={each_city}&appid={weather_api_key}'#rpl each_cities cities[counter]
    weather_response=requests.get(query_url)
    weather_data=weather_response.json()
    counter = counter + 1
 
    try:
        city_data.append(weather_data['name'])
        lat_data.append(weather_data['coord']['lat'])
        lng_data.append(weather_data['coord']['lon'])
        max_temp_data.append(weather_data['main']['temp_max'])
        humidity_data.append(weather_data['main']['humidity'])
        cloudiness_data.append(weather_data['clouds']['all'])
        wind_speed_data.append(weather_data['wind']['speed'])
        country_data.append(weather_data['sys']['country'])
        date_data.append(weather_data['dt'])
        print(f'Processing record number {len(city_data)} for the city of {each_city}')
        
        
    except:
        print('Skipping City')
        pass
    
    
    #print(lat_data)
# Out:
# Processing record number 1 for the city of hermanus
# Processing record number 2 for the city of cape town
# Processing record number 3 for the city of kaitangata
# Processing record number 4 for the city of hasaki
# Processing record number 5 for the city of komsomolskiy
# Processing record number 6 for the city of punta arenas
# Processing record number 7 for the city of yumen
# Processing record number 8 for the city of tuktoyaktuk
# Processing record number 9 for the city of namatanai
# Processing record number 10 for the city of puerto ayora
# Processing record number 11 for the city of kavieng
# Processing record number 12 for the city of castro
# Processing record number 13 for the city of barrow
# Processing record number 14 for the city of bantry
# Skipping City
# Skipping City
# Processing record number 15 for the city of torbay
# Processing record number 16 for the city of bluff
# Processing record number 17 for the city of thayetmyo
# Processing record number 18 for the city of ushuaia
# Processing record number 19 for the city of la asuncion
# Processing record number 20 for the city of ajaccio
# Processing record number 21 for the city of constantine
# Processing record number 22 for the city of thompson
# Processing record number 23 for the city of portland
# Processing record number 24 for the city of yellowknife
# Processing record number 25 for the city of ilebo
# Processing record number 26 for the city of labytnangi
# Processing record number 27 for the city of chara
# Processing record number 28 for the city of albany
# Skipping City
# Processing record number 29 for the city of mar del plata
# Processing record number 30 for the city of vaini
# Processing record number 31 for the city of hovd
# Skipping City
# Processing record number 32 for the city of ponta do sol
# Processing record number 33 for the city of hobart
# Processing record number 34 for the city of sao joao da barra
# Processing record number 35 for the city of victoria
# Processing record number 36 for the city of oranjemund
# Processing record number 37 for the city of georgetown
# Processing record number 38 for the city of mackay
# Processing record number 39 for the city of busselton
# Processing record number 40 for the city of rikitea
# Processing record number 41 for the city of mount gambier
# Processing record number 42 for the city of vestmannaeyjar
# Skipping City
# Processing record number 43 for the city of katsuura
# Processing record number 44 for the city of mataura
# Skipping City
# Processing record number 45 for the city of atar
# Processing record number 46 for the city of longyearbyen
# Processing record number 47 for the city of mahebourg
# Skipping City
# Processing record number 48 for the city of avarua
# Processing record number 49 for the city of tiksi
# Processing record number 50 for the city of bambous virieux
# Processing record number 51 for the city of timbiqui
# Processing record number 52 for the city of durant
# Processing record number 53 for the city of anloga
# Processing record number 54 for the city of lata
# Processing record number 55 for the city of itoman
# Processing record number 56 for the city of beidao
# Processing record number 57 for the city of antalaha
# Processing record number 58 for the city of arraial do cabo
# Processing record number 59 for the city of kupang
# Processing record number 60 for the city of huarmey
# Processing record number 61 for the city of mitsamiouli
# Processing record number 62 for the city of weatherford
# Processing record number 63 for the city of doha
# Processing record number 64 for the city of port lincoln
# Processing record number 65 for the city of goba
# Processing record number 66 for the city of aklavik
# Processing record number 67 for the city of umm kaddadah
# Skipping City
# Processing record number 68 for the city of vigrestad
# Processing record number 69 for the city of port alfred
# Skipping City
# Processing record number 70 for the city of nikolskoye
# Processing record number 71 for the city of anyksciai
# Processing record number 72 for the city of devonport
# Processing record number 73 for the city of tasiilaq
# Skipping City
# Processing record number 74 for the city of korla
# Skipping City
# Processing record number 75 for the city of derbent
# Processing record number 76 for the city of hambantota
# Processing record number 77 for the city of terrace bay
# Processing record number 78 for the city of dikson
# Processing record number 79 for the city of saint-philippe
# Processing record number 80 for the city of beringovskiy
# Skipping City
# Skipping City
# Processing record number 81 for the city of jacqueville
# Processing record number 82 for the city of saldanha
# Processing record number 83 for the city of jacareacanga
# Processing record number 84 for the city of vila do maio
# Processing record number 85 for the city of bengkulu
# Processing record number 86 for the city of brae
# Processing record number 87 for the city of goure
# Processing record number 88 for the city of nchelenge
# Processing record number 89 for the city of new norfolk
# Processing record number 90 for the city of hirara
# Processing record number 91 for the city of bethel
# Processing record number 92 for the city of severo-kurilsk
# Processing record number 93 for the city of chuy
# Skipping City
# Processing record number 94 for the city of biak
# Processing record number 95 for the city of qaanaaq
# Processing record number 96 for the city of chapais
# Processing record number 97 for the city of pauini
# Processing record number 98 for the city of kirkwood
# Processing record number 99 for the city of sao filipe
# Processing record number 100 for the city of ahipara
# Processing record number 101 for the city of bowen
# Processing record number 102 for the city of carmo do rio claro
# Processing record number 103 for the city of ribeira grande
# Processing record number 104 for the city of airai
# Processing record number 105 for the city of puerto gaitan
# Processing record number 106 for the city of east london
# Processing record number 107 for the city of ilulissat
# Processing record number 108 for the city of hokitika
# Processing record number 109 for the city of waipawa
# Processing record number 110 for the city of tomatlan
# Processing record number 111 for the city of tongchuan
# Processing record number 112 for the city of coremas
# Processing record number 113 for the city of oum hadjer
# Processing record number 114 for the city of dunedin
# Processing record number 115 for the city of khatanga
# Processing record number 116 for the city of bandundu
# Processing record number 117 for the city of fairbanks
# Processing record number 118 for the city of teknaf
# Processing record number 119 for the city of sasovo
# Processing record number 120 for the city of kapaa
# Processing record number 121 for the city of lang son
# Processing record number 122 for the city of mehran
# Processing record number 123 for the city of thinadhoo
# Processing record number 124 for the city of nouadhibou
# Processing record number 125 for the city of kalbay
# Processing record number 126 for the city of teguldet
# Processing record number 127 for the city of yokadouma
# Processing record number 128 for the city of batagay
# Processing record number 129 for the city of cherskiy
# Processing record number 130 for the city of dukat
# Processing record number 131 for the city of lensk
# Skipping City
# Processing record number 132 for the city of hilo
# Processing record number 133 for the city of anjozorobe
# Processing record number 134 for the city of saint george
# Processing record number 135 for the city of salalah
# Processing record number 136 for the city of newport
# Processing record number 137 for the city of lasa
# Processing record number 138 for the city of taitung
# Processing record number 139 for the city of vestmanna
# Skipping City
# Processing record number 140 for the city of cidreira
# Processing record number 141 for the city of chokurdakh
# Processing record number 142 for the city of broome
# Processing record number 143 for the city of aden
# Processing record number 144 for the city of noumea
# Processing record number 145 for the city of guanica
# Processing record number 146 for the city of atasu
# Processing record number 147 for the city of butaritari
# Processing record number 148 for the city of nantucket
# Processing record number 149 for the city of jalu
# Processing record number 150 for the city of jamestown
# Processing record number 151 for the city of camargo
# Skipping City
# Processing record number 152 for the city of saint-francois
# Processing record number 153 for the city of sengiley
# Processing record number 154 for the city of namibe
# Processing record number 155 for the city of san julian
# Processing record number 156 for the city of santa vitoria do palmar
# Skipping City
# Skipping City
# Processing record number 157 for the city of cabo san lucas
# Processing record number 158 for the city of aosta
# Processing record number 159 for the city of peniche
# Processing record number 160 for the city of luderitz
# Processing record number 161 for the city of tezu
# Processing record number 162 for the city of upernavik
# Processing record number 163 for the city of tabou
# Processing record number 164 for the city of orotukan
# Processing record number 165 for the city of bandraboua
# Processing record number 166 for the city of praya
# Processing record number 167 for the city of griffith
# Processing record number 168 for the city of amapa
# Processing record number 169 for the city of hithadhoo
# Processing record number 170 for the city of touros
# Processing record number 171 for the city of kruisfontein
# Processing record number 172 for the city of danshui
# Processing record number 173 for the city of bredasdorp
# Skipping City
# Processing record number 174 for the city of ostrovnoy
# Processing record number 175 for the city of paamiut
# Processing record number 176 for the city of ekhabi
# Processing record number 177 for the city of ponta delgada
# Processing record number 178 for the city of madang
# Processing record number 179 for the city of moree
# Processing record number 180 for the city of pachino
# Processing record number 181 for the city of geraldton
# Skipping City
# Processing record number 182 for the city of clyde river
# Processing record number 183 for the city of ankara
# Skipping City
# Processing record number 184 for the city of bakchar
# Processing record number 185 for the city of coos bay
# Processing record number 186 for the city of la ronge
# Processing record number 187 for the city of plettenberg bay
# Processing record number 188 for the city of burdur
# Processing record number 189 for the city of soyo
# Processing record number 190 for the city of valence
# Skipping City
# Processing record number 191 for the city of souillac
# Processing record number 192 for the city of myanaung
# Processing record number 193 for the city of ambovombe
# Processing record number 194 for the city of gambo
# Processing record number 195 for the city of metlaltoyuca
# Processing record number 196 for the city of ikom
# Processing record number 197 for the city of ossora
# Processing record number 198 for the city of port blair
# Processing record number 199 for the city of zeerust
# Processing record number 200 for the city of atuona
# Processing record number 201 for the city of lavrentiya
# Processing record number 202 for the city of ulaangom
# Processing record number 203 for the city of moncao
# Processing record number 204 for the city of verkhnyaya inta
# Processing record number 205 for the city of saskylakh
# Processing record number 206 for the city of smithers
# Processing record number 207 for the city of bestobe
# Processing record number 208 for the city of barranca
# Processing record number 209 for the city of palauig
# Processing record number 210 for the city of pevek
# Processing record number 211 for the city of paramonga
# Processing record number 212 for the city of dumas
# Processing record number 213 for the city of hofn
# Processing record number 214 for the city of norman wells
# Processing record number 215 for the city of tebingtinggi
# Processing record number 216 for the city of ankazoabo
# Processing record number 217 for the city of esperance
# Processing record number 218 for the city of narsaq
# Processing record number 219 for the city of leningradskiy
# Processing record number 220 for the city of broken hill
# Processing record number 221 for the city of kahului
# Processing record number 222 for the city of codrington
# Processing record number 223 for the city of atambua
# Processing record number 224 for the city of aksu
# Processing record number 225 for the city of nome
# Processing record number 226 for the city of tecoanapa
# Skipping City
# Skipping City
# Processing record number 227 for the city of yerbogachen
# Processing record number 228 for the city of kaka
# Processing record number 229 for the city of porto novo
# Processing record number 230 for the city of la orilla
# Processing record number 231 for the city of candolim
# Processing record number 232 for the city of kodiak
# Processing record number 233 for the city of east liverpool
# Processing record number 234 for the city of saqqez
# Processing record number 235 for the city of hailar
# Processing record number 236 for the city of petropavlovsk-kamchatskiy
# Processing record number 237 for the city of shebalino
# Processing record number 238 for the city of harrismith
# Processing record number 239 for the city of awbari
# Processing record number 240 for the city of laguna
# Processing record number 241 for the city of altay
# Skipping City
# Processing record number 242 for the city of fort morgan
# Processing record number 243 for the city of caruray
# Processing record number 244 for the city of malibu
# Processing record number 245 for the city of diego de almagro
# Processing record number 246 for the city of lorengau
# Processing record number 247 for the city of decatur
# Processing record number 248 for the city of horta
# Processing record number 249 for the city of labuhan
# Processing record number 250 for the city of lagoa
# Skipping City
# Processing record number 251 for the city of san patricio
# Processing record number 252 for the city of kamenka
# Processing record number 253 for the city of port hawkesbury
# Processing record number 254 for the city of bodden town
# Processing record number 255 for the city of carupano
# Processing record number 256 for the city of yantal
# Processing record number 257 for the city of tura
# Processing record number 258 for the city of lebu
# Processing record number 259 for the city of nuuk
# Processing record number 260 for the city of oistins
# Processing record number 261 for the city of alofi
# Processing record number 262 for the city of neuquen
# Processing record number 263 for the city of ternate
# Processing record number 264 for the city of muros
# Processing record number 265 for the city of adrar
# Processing record number 266 for the city of khulo
# Processing record number 267 for the city of saint-pierre
# Skipping City
# Processing record number 268 for the city of qandala
# Processing record number 269 for the city of port elizabeth
# Processing record number 270 for the city of nara
# Processing record number 271 for the city of vostok
# Processing record number 272 for the city of ostersund
# Processing record number 273 for the city of lomza
# Processing record number 274 for the city of starosubkhangulovo
# Processing record number 275 for the city of kenai
# Processing record number 276 for the city of jijiang
# Processing record number 277 for the city of roblin
# Processing record number 278 for the city of cocachacra
# Processing record number 279 for the city of marsa matruh
# Processing record number 280 for the city of mayo
# Processing record number 281 for the city of dingle
# Processing record number 282 for the city of caravelas
# Skipping City
# Processing record number 283 for the city of zhangjiakou
# Processing record number 284 for the city of berlevag
# Processing record number 285 for the city of ganzhou
# Processing record number 286 for the city of candido de abreu
# Processing record number 287 for the city of lima
# Processing record number 288 for the city of yurimaguas
# Processing record number 289 for the city of arvika
# Processing record number 290 for the city of robinson
# Processing record number 291 for the city of dragor
# Processing record number 292 for the city of karratha
# Processing record number 293 for the city of rongcheng
# Processing record number 294 for the city of pangkalanbuun
# Processing record number 295 for the city of voyvozh
# Processing record number 296 for the city of nha trang
# Processing record number 297 for the city of zelenoborskiy
# Processing record number 298 for the city of novoagansk
# Skipping City
# Processing record number 299 for the city of palmares do sul
# Processing record number 300 for the city of roebourne
# Processing record number 301 for the city of shelbyville
# Processing record number 302 for the city of acapulco
# Processing record number 303 for the city of warman
# Processing record number 304 for the city of nuevo laredo
# Skipping City
# Processing record number 305 for the city of norsup
# Processing record number 306 for the city of ravar
# Processing record number 307 for the city of batticaloa
# Processing record number 308 for the city of igarka
# Processing record number 309 for the city of roma
# Processing record number 310 for the city of corinto
# Skipping City
# Processing record number 311 for the city of san cristobal
# Processing record number 312 for the city of iguape
# Processing record number 313 for the city of envira
# Processing record number 314 for the city of gazli
# Processing record number 315 for the city of lethem
# Processing record number 316 for the city of marzuq
# Processing record number 317 for the city of poli
# Skipping City
# Skipping City
# Processing record number 318 for the city of umm lajj
# Processing record number 319 for the city of lipari
# Processing record number 320 for the city of mehamn
# Processing record number 321 for the city of pasighat
# Processing record number 322 for the city of saint pete beach
# Processing record number 323 for the city of silopi
# Processing record number 324 for the city of coquimbo
# Processing record number 325 for the city of cayenne
# Processing record number 326 for the city of belmonte
# Processing record number 327 for the city of razole
# Processing record number 328 for the city of trairi
# Processing record number 329 for the city of belyy yar
# Processing record number 330 for the city of la cruz
# Processing record number 331 for the city of kodinsk
# Skipping City
# Processing record number 332 for the city of black river
# Processing record number 333 for the city of anadyr
# Processing record number 334 for the city of aswan
# Processing record number 335 for the city of sitka
# Processing record number 336 for the city of praia
# Processing record number 337 for the city of carnarvon
# Processing record number 338 for the city of riyadh
# Skipping City
# Processing record number 339 for the city of malanje
# Processing record number 340 for the city of ciudad bolivar
# Processing record number 341 for the city of novo aripuana
# Processing record number 342 for the city of axim
# Processing record number 343 for the city of flin flon
# Processing record number 344 for the city of paita
# Processing record number 345 for the city of pichayevo
# Processing record number 346 for the city of constitucion
# Processing record number 347 for the city of waynesville
# Processing record number 348 for the city of nagutskoye
# Processing record number 349 for the city of provideniya
# Processing record number 350 for the city of jadu
# Processing record number 351 for the city of ambilobe
# Processing record number 352 for the city of guarapari
# Processing record number 353 for the city of hualmay
# Processing record number 354 for the city of saint-augustin
# Processing record number 355 for the city of sinnamary
# Processing record number 356 for the city of auki
# Processing record number 357 for the city of amot
# Processing record number 358 for the city of pacific grove
# Processing record number 359 for the city of pedernales
# Skipping City
# Processing record number 360 for the city of bousso
# Processing record number 361 for the city of sistranda
# Processing record number 362 for the city of tongling
# Processing record number 363 for the city of pitimbu
# Processing record number 364 for the city of vilhena
# Processing record number 365 for the city of san jose
# Processing record number 366 for the city of turayf
# Processing record number 367 for the city of nanortalik
# Processing record number 368 for the city of urussu
# Processing record number 369 for the city of russell
# Processing record number 370 for the city of port augusta
# Processing record number 371 for the city of klaksvik
# Processing record number 372 for the city of tautira
# Skipping City
# Processing record number 373 for the city of rajpipla
# Processing record number 374 for the city of pisco
# Processing record number 375 for the city of bonthe
# Processing record number 376 for the city of seoul
# Processing record number 377 for the city of pombia
# Skipping City
# Processing record number 378 for the city of ustye
# Processing record number 379 for the city of san rafael
# Processing record number 380 for the city of misratah
# Processing record number 381 for the city of fortuna
# Processing record number 382 for the city of bosilegrad
# Processing record number 383 for the city of dakar
# Processing record number 384 for the city of mayya
# Processing record number 385 for the city of mozarlandia
# Processing record number 386 for the city of tigre
# Processing record number 387 for the city of port hardy
# Processing record number 388 for the city of tilichiki
# Processing record number 389 for the city of marfino
# Processing record number 390 for the city of wanaka
# Processing record number 391 for the city of porto belo
# Processing record number 392 for the city of buala
# Processing record number 393 for the city of saint-georges
# Processing record number 394 for the city of champerico
# Processing record number 395 for the city of scottsbluff
# Processing record number 396 for the city of san javier
# Processing record number 397 for the city of bathsheba
# Processing record number 398 for the city of vardo
# Processing record number 399 for the city of camacha
# Processing record number 400 for the city of usinsk
# Processing record number 401 for the city of mandurah
# Processing record number 402 for the city of muisne
# Processing record number 403 for the city of kloulklubed
# Processing record number 404 for the city of merritt
# Processing record number 405 for the city of santa rosa
# Processing record number 406 for the city of necochea
# Processing record number 407 for the city of ajdabiya
# Processing record number 408 for the city of posevnaya
# Processing record number 409 for the city of garden city
# Processing record number 410 for the city of pochutla
# Processing record number 411 for the city of marsh harbour
# Processing record number 412 for the city of solnechnyy
# Processing record number 413 for the city of teluknaga
# Processing record number 414 for the city of bafq
# Processing record number 415 for the city of ocampo
# Processing record number 416 for the city of kirakira
# Processing record number 417 for the city of hervey bay
# Processing record number 418 for the city of pangnirtung
# Processing record number 419 for the city of botro
# Processing record number 420 for the city of mpika
# Processing record number 421 for the city of rundu
# Processing record number 422 for the city of kirensk
# Processing record number 423 for the city of flinders
# Processing record number 424 for the city of bull savanna
# Processing record number 425 for the city of taltal
# Processing record number 426 for the city of guaruja
# Processing record number 427 for the city of ormara
# Processing record number 428 for the city of naze
# Skipping City
# Processing record number 429 for the city of qaqortoq
# Processing record number 430 for the city of qasigiannguit
# Processing record number 431 for the city of bulgan
# Processing record number 432 for the city of kuching
# Processing record number 433 for the city of gboko
# Processing record number 434 for the city of hangu
# Processing record number 435 for the city of khlung
# Processing record number 436 for the city of zhanaozen
# Processing record number 437 for the city of tres picos
# Processing record number 438 for the city of suihua
# Processing record number 439 for the city of trinidad
# Processing record number 440 for the city of quatre cocos
# Processing record number 441 for the city of puerto leguizamo
# Skipping City
# Processing record number 442 for the city of abu kamal
# Processing record number 443 for the city of saryozek
# Processing record number 444 for the city of kaeo
# Processing record number 445 for the city of half moon bay
# Processing record number 446 for the city of araguari
# Processing record number 447 for the city of yarada
# Processing record number 448 for the city of huntington
# Processing record number 449 for the city of glace bay
# Processing record number 450 for the city of yelandur
# Skipping City
# Processing record number 451 for the city of faanui
# Processing record number 452 for the city of senanga
# Skipping City
# Processing record number 453 for the city of samandag
# Processing record number 454 for the city of honiara
# Processing record number 455 for the city of cockburn town
# Processing record number 456 for the city of kropotkin
# Processing record number 457 for the city of primorsk
# Processing record number 458 for the city of sibolga
# Processing record number 459 for the city of tuatapere
# Skipping City
# Processing record number 460 for the city of estremoz
# Processing record number 461 for the city of quito
# Processing record number 462 for the city of sulina
# Skipping City
# Processing record number 463 for the city of karangasem
# Processing record number 464 for the city of encrucijada
# Processing record number 465 for the city of praia da vitoria
# Skipping City
# Processing record number 466 for the city of porto velho
# Processing record number 467 for the city of burnie
# Processing record number 468 for the city of grand gaube
# Processing record number 469 for the city of chhabra
# Processing record number 470 for the city of jinchang
# Processing record number 471 for the city of iraray
# Processing record number 472 for the city of san carlos de bariloche
# Processing record number 473 for the city of falmouth
# Processing record number 474 for the city of kieta
# Processing record number 475 for the city of taoudenni
# Processing record number 476 for the city of zhadovka
# Processing record number 477 for the city of vila velha
# Processing record number 478 for the city of berwick
# Processing record number 479 for the city of agasegyhaza
# Processing record number 480 for the city of iracoubo
# Processing record number 481 for the city of oyon
# Processing record number 482 for the city of zverinogolovskoye
# Processing record number 483 for the city of port-gentil
# Processing record number 484 for the city of kudahuvadhoo
# Processing record number 485 for the city of faya
# Processing record number 486 for the city of ituiutaba
# Processing record number 487 for the city of akyab
# Processing record number 488 for the city of olinda
# Processing record number 489 for the city of sola
# Processing record number 490 for the city of porbandar
# Processing record number 491 for the city of bilibino
# Skipping City
# Processing record number 492 for the city of olafsvik
# Processing record number 493 for the city of ambon
# Processing record number 494 for the city of harper
# Processing record number 495 for the city of skjervoy
# Processing record number 496 for the city of panguna
# Processing record number 497 for the city of roald
# Processing record number 498 for the city of novaya igirma
# Processing record number 499 for the city of barcelos
# Processing record number 500 for the city of tiznit
# Processing record number 501 for the city of sabak
# Processing record number 502 for the city of sayyan
# Processing record number 503 for the city of yining
# Processing record number 504 for the city of yinchuan
# Processing record number 505 for the city of isangel
# Processing record number 506 for the city of fare
# Processing record number 507 for the city of tarumovka
# Processing record number 508 for the city of los llanos de aridane
# Processing record number 509 for the city of soe
# Processing record number 510 for the city of mae hong son
# Processing record number 511 for the city of turbat
# Processing record number 512 for the city of lofthus
# Processing record number 513 for the city of luanda
# Processing record number 514 for the city of kuldur
# Processing record number 515 for the city of lubumbashi
# Skipping City
# Processing record number 516 for the city of koshki
# Processing record number 517 for the city of ouallam
# Processing record number 518 for the city of avera
# Processing record number 519 for the city of kovernino
# Processing record number 520 for the city of nambucca heads
# Processing record number 521 for the city of marawi
# Processing record number 522 for the city of sibu
# Processing record number 523 for the city of eydhafushi
# Processing record number 524 for the city of monte patria
# Processing record number 525 for the city of fukue
# Processing record number 526 for the city of jiazi
# Processing record number 527 for the city of sulangan
# Skipping City
# Processing record number 528 for the city of tianjin
# Processing record number 529 for the city of asfi
# Skipping City
# Skipping City
# Processing record number 530 for the city of kostomuksha
# Processing record number 531 for the city of saint anthony
# Processing record number 532 for the city of uruguaiana
# Processing record number 533 for the city of san quintin
# Processing record number 534 for the city of topolobampo
# Processing record number 535 for the city of amahai
# Processing record number 536 for the city of aurangabad
# Processing record number 537 for the city of meadow lake
# Skipping City
# Processing record number 538 for the city of guerrero negro
# Processing record number 539 for the city of lamu
# Processing record number 540 for the city of kavaratti
# Processing record number 541 for the city of sao gabriel da cachoeira
# Processing record number 542 for the city of matay
# Skipping City
# Processing record number 543 for the city of shakawe
# Processing record number 544 for the city of ruteng
# Processing record number 545 for the city of suntar
# Processing record number 546 for the city of ketchikan
# Processing record number 547 for the city of talnakh
# Processing record number 548 for the city of dafeng
# Processing record number 549 for the city of ucluelet
# Processing record number 550 for the city of shagonar

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data_df = pd.DataFrame({'City': city_data,
                        'Latitude': lat_data,
                        'Longitude': lng_data,
                        'Max Temp': max_temp_data,
                        'Humidity': humidity_data,
                        'Cloudiness': cloudiness_data,
                        'Wind Speed': wind_speed_data,
                        'Country': country_data,
                        'Data': date_data})


data_df.head(10)
# Out:
#               City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0         Hermanus  -34.4187    19.2345    292.04        86           4
# 1        Cape Town  -33.9258    18.4232    294.82        73           0
# 2       Kaitangata  -46.2817   169.8464    289.26        70          76
# 3           Hasaki   35.7333   140.8333    269.15        80          20
# 4  Yangi Marg`ilon   40.4272    71.7189    275.15        51         100
# 5     Punta Arenas  -53.1500   -70.9167    287.15        51           0
# 6            Yumen   40.2833    97.2000    268.04        73           0
# 7      Tuktoyaktuk   69.4541  -133.0374    236.15        67          40
# 8        Namatanai   -3.6667   152.4333    301.30        73         100
# 9     Puerto Ayora   -0.7393   -90.3518    303.15        62           0
#
#    Wind Speed Country        Data
# 0        0.45      ZA  1612042581
# 1        2.06      ZA  1612042458
# 2        1.79      NZ  1612042023
# 3        1.03      JP  1612041809
# 4        2.06      UZ  1612042039
# 5       11.83      CL  1612042582
# 6       10.87      CN  1612042582
# 7        1.03      CA  1612042582
# 8        5.46      PG  1612042611
# 9        6.17      EC  1612042583

# %%
data_df.to_csv('..\output_data\WeatherPY.csv')

# %%
data_df.describe()
# Out:
#          Latitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.401464   17.886246  283.625618   72.340000   51.738182    3.867382
# std     32.386130   89.861654   18.199319   19.121099   39.644603    2.737166
# min    -54.800000 -175.200000  228.690000   14.000000    0.000000    0.080000
# 25%     -7.427950  -61.106300  273.150000   62.000000    4.250000    1.697500
# 50%     22.180350   20.777350  289.820000   76.000000   55.000000    3.205000
# 75%     45.593525   97.776375  298.150000   87.000000   90.000000    5.155000
# max     78.218600  179.316700  307.980000  100.000000  100.000000   15.950000
#
#                Data
# count  5.500000e+02
# mean   1.612043e+09
# std    1.242664e+02
# min    1.612042e+09
# 25%    1.612043e+09
# 50%    1.612043e+09
# 75%    1.612043e+09
# max    1.612043e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_filter=data_df.loc[:,'Humidity']<=100
filter_data_df=data_df.loc[humidity_filter,:]
filter_data_df.describe()
# Out:
#          Latitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.401464   17.886246  283.625618   72.340000   51.738182    3.867382
# std     32.386130   89.861654   18.199319   19.121099   39.644603    2.737166
# min    -54.800000 -175.200000  228.690000   14.000000    0.000000    0.080000
# 25%     -7.427950  -61.106300  273.150000   62.000000    4.250000    1.697500
# 50%     22.180350   20.777350  289.820000   76.000000   55.000000    3.205000
# 75%     45.593525   97.776375  298.150000   87.000000   90.000000    5.155000
# max     78.218600  179.316700  307.980000  100.000000  100.000000   15.950000
#
#                Data
# count  5.500000e+02
# mean   1.612043e+09
# std    1.242664e+02
# min    1.612042e+09
# 25%    1.612043e+09
# 50%    1.612043e+09
# 75%    1.612043e+09
# max    1.612043e+09

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_over_filter=data_df.loc[:,'Humidity']>100
filter_over_df=data_df.loc[humidity_over_filter, :]
list(filter_over_df.index)
filter_over_df.index
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_lat=filter_data_df['Latitude']
y_maxtemp = filter_data_df['Max Temp']

plt.scatter(x_lat, y_maxtemp,)
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel ("Max Temp")
plt.grid(True)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_lat=filter_data_df['Latitude']
y_humidity = filter_data_df['Humidity']

plt.scatter(x_lat, y_humidity,)
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel ("Humidity")
plt.grid(True)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_lat=filter_data_df['Latitude']
y_clouds = filter_data_df['Cloudiness']

plt.scatter(x_lat, y_clouds,)
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel ("Cloudiness")
plt.grid(True)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_lat=filter_data_df['Latitude']
y_wind = filter_data_df['Wind Speed']

plt.scatter(x_lat, y_wind,)
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel ("Wind Speed")
plt.grid(True)

# %%
northern_df=filter_data_df.loc[:,'Latitude']>=0
filter_northern_df=filter_data_df.loc[northern_df, :]
filter_northern_df.describe()
# Out:
#          Latitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean    37.300963   12.557332  277.943921   71.013158   50.621053    3.997237
# std     20.061835   86.362349   19.105373   20.263758   39.864329    2.885605
# min      0.533300 -173.300000  228.690000   14.000000    0.000000    0.080000
# 25%     20.830125  -66.011375  267.225000   60.000000    1.000000    1.670000
# 50%     38.444200   18.081900  282.500000   76.000000   50.000000    3.445000
# 75%     54.023925   86.966650  295.087500   86.000000   90.000000    5.382500
# max     78.218600  179.316700  307.980000  100.000000  100.000000   15.950000
#
#                Data
# count  3.800000e+02
# mean   1.612043e+09
# std    1.310733e+02
# min    1.612042e+09
# 25%    1.612043e+09
# 50%    1.612043e+09
# 75%    1.612043e+09
# max    1.612043e+09

# %%
southern_df = filter_data_df.loc[:,'Latitude']<0
filter_southern_df=filter_data_df.loc[southern_df, :]
filter_southern_df.describe()
# Out:
#          Latitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  170.000000  170.000000  170.000000  170.000000  170.000000  170.000000
# mean   -20.609182   29.797935  296.325882   75.305882   54.235294    3.577118
# std     13.187824   96.432598    4.747393   15.938880   39.150188    2.354140
# min    -54.800000 -175.200000  282.820000   14.000000    0.000000    0.380000
# 25%    -32.362500  -57.440200  292.067500   67.000000   19.250000    1.790000
# 50%    -20.112250   24.051500  297.840000   78.000000   60.500000    3.090000
# 75%     -9.165850  124.740375  300.150000   88.000000   98.500000    5.140000
# max     -0.130300  175.515300  304.470000  100.000000  100.000000   11.830000
#
#                Data
# count  1.700000e+02
# mean   1.612043e+09
# std    1.076845e+02
# min    1.612042e+09
# 25%    1.612043e+09
# 50%    1.612043e+09
# 75%    1.612043e+09
# max    1.612043e+09

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = filter_northern_df['Latitude']
y_values = filter_northern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(100,250),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.grid(True)
plt.show()
#plt.savefig('..\output_data\NH_Humidity.png')
# Out:
# The r-squared is: 0.7318634366232237

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = filter_southern_df['Latitude']
y_values = filter_southern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.grid(True)
plt.show()
plt.savefig('..\output_data\SH_Humidity.png')
# Out:
# The r-squared is: 0.3663556138627642

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = filter_northern_df['Latitude']
y_values = filter_northern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.grid(True)
plt.show()
#plt.savefig('..\output_data\NH_Humidity.png')
# Out:
# The r-squared is: 0.09335209723141509

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = filter_southern_df['Latitude']
y_values = filter_southern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.grid(True)
plt.show()
plt.savefig('..\output_data\SH_Humidity.png')
# Out:
# The r-squared is: 0.08947247518684019

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = filter_northern_df['Latitude']
y_values = filter_northern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.grid(True)
plt.show()
#plt.savefig('..\output_data\NH_Cloudiness.png')
# Out:
# The r-squared is: 0.05472907131896373

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = filter_southern_df['Latitude']
y_values = filter_southern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.grid(True)
plt.show()
#plt.savefig('..\output_data\SH_Cloudiness.png')
# Out:
# The r-squared is: 0.09492097763612069

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = filter_northern_df['Latitude']
y_values = filter_northern_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,5),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.grid(True)
plt.show()
#plt.savefig('..\output_data\NH_Wind_Speed.png')
# Out:
# The r-squared is: 0.0007801855037577606

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = filter_southern_df['Latitude']
y_values = filter_southern_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,10),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.grid(True)
plt.show()
plt.savefig('..\output_data\SH_Wind_Speed.png')
# Out:
# The r-squared is: 0.014637195566153907
